# %%
import pandas as pd 
import numpy as np
TWEET_DATA = pd.read_csv("data.csv")

TWEET_DATA.head()
# Out:
#         user_id created_at                                               text  \
# 0  1.380000e+18  3/29/2021  b"'Satgas COVID-19 mengaku kepatuhan masyaraka...
# 1  1.380000e+18  3/29/2021  b"'RT @ProfesorZubairi: Hari ini saya akan bah...
# 2  1.380000e+18  3/29/2021  b"'@sshayeol agak aneh gk sih kalo alasannya k...
# 3  1.380000e+18  3/29/2021  b"'Bolehkah Kita Balik Raya Di Kampung Tahun I...
# 4  1.380000e+18  3/29/2021  b"'27. biggest wish adalah masuk surga bersama...
#
#    label
# 0     -1
# 1      1
# 2     -1
# 3      1
# 4      1

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
TWEET_DATA['text'] = [i.lower() for i in TWEET_DATA.text.astype(str)]

print('Case Folding Result : \n')
print(TWEET_DATA['text'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    b"'satgas covid-19 mengaku kepatuhan masyaraka...
# 1    b"'rt @profesorzubairi: hari ini saya akan bah...
# 2    b"'@sshayeol agak aneh gk sih kalo alasannya k...
# 3    b"'bolehkah kita balik raya di kampung tahun i...
# 4    b"'27. biggest wish adalah masuk surga bersama...
# Name: text, dtype: object

# %%
import string 
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

TWEET_DATA['tweet_tokens'] = TWEET_DATA['text'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(TWEET_DATA['tweet_tokens'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0    [bsatgas, covid, mengaku, kepatuhan, masyaraka...
# 1    [brt, hari, ini, saya, akan, bahas, soal, long...
# 2       [agak, aneh, gk, sih, kalo, alasannya, korona]
# 3    [bbolehkah, kita, balik, raya, di, kampung, ta...
# 4    [biggest, wish, adalah, masuk, surga, bersama,...
# Name: tweet_tokens, dtype: object

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

TWEET_DATA['tweet_tokens_fdist'] = TWEET_DATA['tweet_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(TWEET_DATA['tweet_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(bsatgas, 1), (covid, 1), (mengaku, 1), (kepa...
# 1    [(brt, 1), (hari, 1), (ini, 1), (saya, 1), (ak...
# 2    [(agak, 1), (aneh, 1), (gk, 1), (sih, 1), (kal...
# 3    [(bbolehkah, 1), (kita, 1), (balik, 1), (raya,...
# 4    [(orang, 2), (biggest, 1), (wish, 1), (adalah,...
# Name: tweet_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "brt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'gk', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'nyg', 'hehe', 'pen', 'nan', 'loh', 'rt',
                       '&amp', 'yah','of','guys','dri','ku','kmu'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
#txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
#list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

TWEET_DATA['tweet_tokens_WSW'] = TWEET_DATA['tweet_tokens'].apply(stopwords_removal) 

print(TWEET_DATA['tweet_tokens_WSW'].head())
# Out:
# 0    [bsatgas, covid, mengaku, kepatuhan, masyaraka...
# 1    [bahas, long, covid, sebutannya, diganti, post...
# 2                            [aneh, alasannya, korona]
# 3                           [bbolehkah, raya, kampung]
# 4    [biggest, wish, masuk, surga, orang, orang, sa...
# Name: tweet_tokens_WSW, dtype: object

# %%
print(TWEET_DATA.head())
# Out:
#         user_id created_at                                               text  \
# 0  1.380000e+18  3/29/2021  bsatgas covid mengaku kepatuhan masyarakat ter...
# 1  1.380000e+18  3/29/2021  brt hari ini saya akan bahas soal long covid y...
# 2  1.380000e+18  3/29/2021             agak aneh gk sih kalo alasannya korona
# 3  1.380000e+18  3/29/2021     bbolehkah kita balik raya di kampung tahun ini
# 4  1.380000e+18  3/29/2021   biggest wish adalah masuk surga bersama orang...
#
#    label                                       tweet_tokens  \
# 0     -1  [bsatgas, covid, mengaku, kepatuhan, masyaraka...
# 1      1  [brt, hari, ini, saya, akan, bahas, soal, long...
# 2     -1     [agak, aneh, gk, sih, kalo, alasannya, korona]
# 3      1  [bbolehkah, kita, balik, raya, di, kampung, ta...
# 4      1  [biggest, wish, adalah, masuk, surga, bersama,...
#
#                                   tweet_tokens_fdist  \
# 0  {'bsatgas': 1, 'covid': 1, 'mengaku': 1, 'kepa...
# 1  {'brt': 1, 'hari': 1, 'ini': 1, 'saya': 1, 'ak...
# 2  {'agak': 1, 'aneh': 1, 'gk': 1, 'sih': 1, 'kal...
# 3  {'bbolehkah': 1, 'kita': 1, 'balik': 1, 'raya'...
# 4  {'biggest': 1, 'wish': 1, 'adalah': 1, 'masuk'...
#
#                                     tweet_tokens_WSW
# 0  [bsatgas, covid, mengaku, kepatuhan, masyaraka...
# 1  [bahas, long, covid, sebutannya, diganti, post...
# 2                          [aneh, alasannya, korona]
# 3                         [bbolehkah, raya, kampung]
# 4  [biggest, wish, masuk, surga, orang, orang, sa...

# %%
normalizad_word = pd.read_excel("normalisasi.xlsx")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

TWEET_DATA['tweet_normalized'] = TWEET_DATA['tweet_tokens_WSW'].apply(normalized_term)
TWEET_DATA['tweet_normalized'] = TWEET_DATA['tweet_tokens_WSW'].apply(normalized_term)

TWEET_DATA['tweet_normalized'].head(10)
# Out:
# 0    [satgas, covid, mengaku, kepatuhan, masyarakat...
# 1    [bahas, long, covid, sebutannya, diganti, post...
# 2                            [aneh, alasannya, korona]
# 3                            [bolehkah, raya, kampung]
# 4    [biggest, wish, masuk, surga, orang, orang, sa...
# 5                      [kesehatan, adakah, petandaaaa]
# 6    [bpln, berkomitmen, mendukung, program, vaksin...
# 7    [kenyataan, memaklumkan, perkembangan, kesehat...
# 8    [anggota, dprd, provinsi, lampung, terima, vak...
# 9                       [data, kematian, covid, maret]
# Name: tweet_normalized, dtype: object

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in TWEET_DATA['tweet_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

TWEET_DATA['tweet_tokens_stemmed'] = TWEET_DATA['tweet_normalized'].swifter.apply(get_stemmed_term)
print(TWEET_DATA['tweet_tokens_stemmed'])
# Out:
# 1536
# ------------------------
# satgas : satgas
# covid : covid
# mengaku : aku
# kepatuhan : patuh
# masyarakat : masyarakat
# protokol : protokol
# kesehatan : sehat
# menurun : turun
# dilaksanakannya : laksana
# vaksin : vaksin
# bahas : bahas
# long : long
# sebutannya : sebut
# diganti : ganti
# post : post
# acute : acute
# sequelae : sequelae
# sarscov : sarscov
# pascxexxa : pascxexxa
# aneh : aneh
# alasannya : alas
# korona : korona
# bolehkah : boleh
# raya : raya
# kampung : kampung
# biggest : biggest
# wish : wish
# masuk : masuk
# surga : surga
# orang : orang
# sayangin : sayangin
# konser : konser
# day : day
# belum : belum
# kesampean : sampean
# anjing : anjing
# adakah : ada
# petandaaaa : petandaaaa
# bpln : bpln
# berkomitmen : komitmen
# mendukung : dukung
# program : program
# vaksinasi : vaksinasi
# dijalankan : jalan
# pemerintah : perintah
# diwujudkan : wujud
# vaksinisasi : vaksin
# kenyataan : nyata
# memaklumkan : maklum
# perkembangan : kembang
# kompaun : kompaun
# pelanggaran : langgar
# sop : sop
# kuantan : antan
# barubaru : barubaru
# anggota : anggota
# dprd : dprd
# provinsi : provinsi
# lampung : lampung
# terima : terima
# vaksinxcxacovid : vaksinxcxacovid
# data : data
# kematian : mati
# maret : maret
# yamani : yamani
# salam : salam
# albakri : albakri
# hadith : hadith
# khusus : khusus
# double : double
# standard : standard
# menghukum : hukum
# pencuri : curi
# amaran : amar
# dalxexxa : dalxexxa
# terapkan : terap
# pendisiplinan : disiplin
# prokes : prokes
# antisipasi : antisipasi
# personil : personil
# sat : sat
# polair : polair
# polres : polres
# jembrana : jembrana
# lakukan : laku
# kurve : kurve
# kebersihan : bersih
# siscajkt : siscajkt
# pandemi : pandemi
# susah : susah
# dapatkan : dapat
# uang : uang
# sampingan : samping
# yuk : yuk
# langsung : langsung
# hubungi : hubung
# whatsapp : whatsapp
# gt : gt
# selamat : selamat
# hut : hut
# rsud : rsud
# panembahan : panembahan
# senopati : senopati
# bantul : bantul
# hati : hati
# tekad : tekad
# pelayanan : layan
# xfxfxxaa : xfxfxxaa
# xexxa : xexxa
# perdana : perdana
# menteri : menteri
# tan : tan
# sri : sri
# muhyiddin : muhyiddin
# yassin : yassin
# jaminan : jamin
# kerajaan : raja
# berusaha : usaha
# membantu : bantu
# memulihkan : pulih
# kehidupan : hidup
# rakyaxexxa : rakyaxexxa
# dosen : dosen
# usu : usu
# meninggal : tinggal
# terpapar : papar
# kathrinajkt : kathrinajkt
# kumulatif : kumulatif
# konfirmasi : konfirmasi
# positif : positif
# indonesia : indonesia
# mencapai : capai
# juta : juta
# tepatnya : tepat
# sexexxa : sexexxa
# bprogram : bprogram
# wujud : wujud
# nyata : nyata
# kesadaran : sadar
# pln : pln
# menekan : tekan
# penyebaran : sebar
# virus : virus
# mexexxa : mexexxa
# marshajkt : marshajkt
# bsecara : bsecara
# bertahap : tahap
# pegawai : pegawai
# memastikanxexxa : memastikanxexxa
# yaudahlah : yaudahlah
# poto : poto
# gapapa : gapapa
# lo : lo
# pake : pake
# alesan : alesan
# gabole : gabole
# kumpul : kumpul
# bxfxfxxc : bxfxfxxc
# pemerkasaan : perkasa
# komuniti : komuniti
# senjata : senjata
# usaha : usaha
# membendung : bendung
# penularan : tular
# xfxfxxc : xfxfxxc
# pantau : pantau
# kawaxexxa : kawaxexxa
# syukram : syukram
# akhi : akh
# sy : sy
# diajak : ajak
# kemenparekraf : kemenparekraf
# negara : negara
# lemuria : lemuria
# mengikuti : ikut
# uji : uji
# coba : coba
# wisata : wisata
# era : era
# graciajkt : graciajkt
# edaran : edar
# pp : pp
# muhammadiyah : muhammadiyah
# tuntunan : tuntun
# ibadah : ibadah
# ramadan : ramadan
# kondisi : kondisi
# darurat : darurat
# astrazeneca : astrazeneca
# sulawesi : sulawesi
# utara : utara
# dihentikan : henti
# warga : warga
# divaksin : vaksin
# merasakxexxa : merasakxexxa
# bvaksin : bvaksin
# dikembangkan : kembang
# lipi : lipi
# ujicoba : ujicoba
# kuartal : kuartal
# ketiga : tiga
# efek : efek
# samping : samping
# makan : makan
# pecel : pecel
# lele : lele
# bbersama : bbersama
# tennis : tennis
# indoor : indoor
# senayan : senayan
# jakarta : jakarta
# memasok : pasok
# listrik : listrik
# infrastruktur : infrastruktur
# lainxexxa : lainxexxa
# titah : titah
# diraja : diraja
# marilah : mari
# bersamasama : bersamasama
# memerangi : rang
# pandemik : pandemik
# menunaikan : tunai
# kewajipan : kewajipan
# mxexxa : mxexxa
# bsistem : bsistem
# pcare : pcare
# inovasi : inovasi
# bpjs : bpjs
# memperlancar : lancar
# vaksinasixexxa : vaksinasixexxa
# kumis : kumis
# pesan : pesan
# menkes : menkes
# ajak : ajak
# keluarga : keluarga
# lansia : lansia
# ayo : ayo
# sobat : sobat
# twips : twips
# target : target
# vaksxexxa : vaksxexxa
# balhamdulillah : balhamdulillah
# alhamdulillah : alhamdulillah
# xfxfxaxd : xfxfxaxd
# bdi : bdi
# pengungsian : ungsi
# pertamina : pertamina
# kelengkapan : lengkap
# pencegahan : cegah
# masker : masker
# hand : hand
# sanitizer : sanitizer
# sertaxexxa : sertaxexxa
# binshaallah : binshaallah
# xfxfxaxbxfxfxaxbxfxfxaxbxfxfxaxb : xfxfxaxbxfxfxaxbxfxfxaxbxfxfxaxb
# indah : indah
# pembatasan : batas
# mobilitas : mobilitas
# efektif : efektif
# tekan : tekan
# budi : budi
# gunadi : gunadi
# sadikin : sadikin
# mengxexxa : mengxexxa
# bbkag : bbkag
# tebingtinggi : tebingtinggi
# barisan : baris
# terdepan : depan
# sosialisasikan : sosialisasi
# airlangga : airlangga
# ppkm : ppkm
# mikro : mikro
# kunci : kunci
# pengendalian : kendali
# depannya : depan
# tingkatkanxexxa : tingkatkanxexxa
# prokesxcxacovid : prokesxcxacovid
# penurunan : turun
# baharu : baharu
# malaysia : malaysia
# petanda : tanda
# cerah : cerah
# menujxexxa : menujxexxa
# terkini : kini
# mac : mac
# xexxaxexxaxexxa : xexxaxexxaxexxa
# iaitu : iaitu
# terendah : rendah
# setakat : takat
# kali : kali
# harian : hari
# bxexxa : bxexxa
# bbhabinkamtibmas : bbhabinkamtibmas
# kel : kel
# meteseh : meteseh
# polsek : polsek
# tembalang : tembalang
# aiptu : aiptu
# saptiawan : saptiawan
# riadi : riadi
# melaks : melaks
# masy : masy
# tetxexxa : tetxexxa
# bkapolres : bkapolres
# tebing : tebing
# xexxxcxa : xexxxcxa
# id : id
# halo : halo
# hindari : hindar
# mengunggah : unggah
# sertifikat : sertifikat
# media : media
# sosial : sosial
# httpxexxa : httpxexxa
# pemutus : putus
# mematuhi : patuh
# ketat : ketat
# memiliki : milik
# imun : imun
# tubuh : tubuh
# kuat : kuat
# tendik : tendik
# ikuti : ikut
# massal : massal
# bsebanyak : bsebanyak
# kanreg : kanreg
# ii : ii
# bkn : bkn
# pns : pns
# ppnpn : ppnpn
# disuntik : suntik
# tahap : tahap
# ruxexxa : ruxexxa
# malam : malam
# railmin : railmin
# sarankan : saran
# pakaian : pakai
# lengan : lengan
# kak : kak
# celananya : celana
# lebixexxa : lebixexxa
# wow : wow
# penyuntikan : sunti
# capai : capai
# berdasarkan : dasar
# dinamika : dinamika
# catatan : catat
# mengenaxexxa : mengenaxexxa
# bmaupun : bmaupun
# isolasi : isolasi
# spt : spt
# hotel : hotel
# wisma : wisma
# atlet : atlet
# berupaya : upaya
# pelayaxexxa : pelayaxexxa
# bmudik : bmudik
# lebaran : lebaran
# dilarang : larang
# sabar : sabar
# terkontrol : kontrol
# btugu : btugu
# simbol : simbol
# perlawanan : lawan
# tugu : tugu
# txexxa : txexxa
# kota : kota
# pemkot : pemkot
# malang : malang
# optimis : optimis
# penanganan : tangan
# bkusendro : bkusendro
# lawan : lawan
# mensukseskan : sukses
# bcegah : bcegah
# patuhi : patuh
# bsudah : bsudah
# memprioritaskan : prioritas
# pasien : pasien
# gagal : gagal
# ginjal : ginjal
# komitmen : komitmen
# kritikal : kritikal
# memutuskan : putus
# rantaian : rantai
# nadxexxa : nadxexxa
# selangor : selangor
# sabah : sabah
# johor : johor
# kl : kl
# sembilan : sembilan
# kesxexxa : kesxexxa
# bsebagai : bsebagai
# salah : salah
# upaya : upaya
# mengurangi : kurang
# ipc : ipc
# melaksanakan : laksana
# peduli : peduli
# menjauh : jauh
# polisi : polisi
# tindakan : tindak
# dikenakan : kena
# pkp : pkp
# ditetapkan : tetap
# byuukk : byuukk
# rajin : rajin
# cuci : cuci
# tangan : tangan
# cegah : cegah
# kanan : kanan
# pertahanan : tahan
# perintah : perintah
# kawalan : kawal
# pergerakan : gera
# bersyarat : syarat
# pkpb : pkpb
# pergerxexxa : pergerxexxa
# bupdate : bupdate
# corona : corona
# ri : ri
# tembus : tembus
# bipc : bipc
# berharp : berharp
# mendorong : dorong
# disiplin : disiplin
# menerapkan : terap
# kesehataxexxa : kesehataxexxa
# bberita : bberita
# siswa : siswa
# tatap : tatap
# muka : muka
# dokter : dokter
# share : share
# blm : blm
# adjem : adjem
# bdiary : bdiary
# manula : manula
# bsekjen : bsekjen
# kemenkes : kemenkes
# tinjau : tinjau
# lokasi : lokasi
# lingkungan : lingkung
# bnn : bnn
# btni : btni
# ad : ad
# kasad : kasad
# jenderal : jenderal
# tni : tni
# andika : andika
# perkasa : perkasa
# mabesad : mabesad
# pemberixexxa : pemberixexxa
# bseorang : bseorang
# asn : asn
# puncak : puncak
# jaya : jaya
# dunia : dunia
# pemulihan : pulih
# pkpp : pkpp
# capp : capp
# pembudayaan : budaya
# norma : norma
# pengisytiharan : pengisytiharan
# proklamasi : proklamasi
# darxexxa : darxexxa
# update : update
# balhamdulliillah : balhamdulliillah
# anak : anak
# sembuh : sembuh
# kehendaknya : hendak
# subhanallah : subhanallah
# bbelum : bbelum
# sinovac : sinovac
# habis : habis
# laper : laper
# btekan : btekan
# bhabinkamtibmas : bhabinkamtibmas
# pahandut : pahandut
# giatkan : giat
# posko : posko
# skalaxcxamikro : skalaxcxamikro
# sampingnya : samping
# wajar : wajar
# expected : expected
# adl : adl
# komunikasi : komunikasi
# risiko : risiko
# bpaskah : bpaskah
# teror : teror
# bom : bom
# bgus : bgus
# muhdlor : muhdlor
# pastikan : pasti
# kabupaten : kabupaten
# sidoarjo : sidoarjo
# peroleh : oleh
# ribu : ribu
# brsj : brsj
# jabar : jabar
# tangani : tangan
# ratusan : ratus
# kecanduan : candu
# gawai : gawai
# akibat : akibat
# bisaa : bisaa
# jadii : jadi
# koo : koo
# nderr : nderr
# karnaa : karnaa
# soalnyaa : soalnyaa
# perusahaan : usaha
# nunda : nunda
# rekrutmen : rekrutmen
# karna : karna
# bsaya : bsaya
# poll : poll
# fasa : fasa
# pemberian : beri
# mahu : mahu
# menerima : terima
# suntikanxexxa : suntikanxexxa
# warganegara : warganegara
# jangkitan : jangkit
# dilaporkan : lapor
# menjadikan : jadi
# covixexxa : covixexxa
# infografis : infografis
# percepatan : cepat
# tanggal : tanggal
# wib : wib
# bagar : bagar
# terhindar : hindar
# kantorxcxagilimanuxexxa : kantorxcxagilimanuxexxa
# bbekalan : bbekalan
# mibggu : mibggu
# bpersonil : bpersonil
# batalyon : batalyon
# pelopor : pelopor
# pengamanan : aman
# rski : rski
# galang : galang
# senin : senin
# rsj : rsj
# bpenerapan : bpenerapan
# dikantor : kantor
# pembuatanxcxasim : pembuatanxcxasim
# bstok : bstok
# terancam : ancam
# menipis : tip
# april : april
# strategi : strategi
# xexxxcxakontan : xexxxcxakontan
# bwalau : bwalau
# berhasil : hasil
# turun : turun
# bdata : bdata
# polandia : polandia
# cet : cet
# bops : bops
# yustisi : yustisi
# polresta : polresta
# yogyakarta : yogyakarta
# gabungan : gabung
# satpolpp : satpolpp
# kegiatan : giat
# himbauan : himbauan
# xexx : xexx
# kontan : kontan
# situasi : situasi
# xcxa : xcxa
# utas : utas
# hafidz : hafidz
# suntikan : sunti
# vakxexxa : vakxexxa
# bayo : bayo
# mencegah : cegah
# pedagang : dagang
# pasar : pasar
# tradisional : tradisional
# genteng : genteng
# salaxexxa : salaxexxa
# pemilihan : pilih
# pengalaman : alam
# kpu : kpu
# menyelenggarakan : selenggara
# proses : proses
# demokrasi : demokrasi
# salxexxa : salxexxa
# bkelurahan : bkelurahan
# koja : koja
# usia : usia
# rptra : rptra
# sindang : sindang
# sebanyaxexxa : sebanyaxexxa
# kecamatan : camat
# zona : zona
# orange : orange
# kotaxcxapekanbaru : kotaxcxapekanbaru
# bkemenag : bkemenag
# jombang : jombang
# tuntaskan : tuntas
# guru : guru
# bwali : bwali
# surabaya : surabaya
# pendirian : diri
# rs : rs
# mal : mal
# cito : cito
# yak : yak
# mengharuskan : harus
# umat : umat
# halu : halu
# mincool : mincool
# cool : cool
# kids : kids
# bayangin : bayangin
# covidxexxa : covidxexxa
# bupati : bupati
# imbau : imbau
# kadis : kad
# kapolres : kapolres
# kuansing : kuansing
# cek : cek
# pelaksanaan : laksana
# vaksinaksi : vaksinaksi
# petugas : tugas
# pelayananxcxapublik : pelayananxcxapublik
# bkasus : bkasus
# memucak : memucak
# negaranegara : negaranegara
# lockdown : lockdown
# semoga : moga
# diserbu : serbu
# kaum : kaum
# konspirasi : konspirasi
# dok : dok
# malas : malas
# ig : ig
# membahas : bahas
# olahraganya : olahraga
# senam : senam
# pagi : pagi
# udah : udah
# jaga : jaga
# jarak : jarak
# bbukannya : bbukannya
# yha : yha
# bsiswa : bsiswa
# sekolah : sekolah
# batam : batam
# ditutup : tutup
# bkegiatan : bkegiatan
# dilaksanakan : laksana
# memenuhi : penuh
# standar : standar
# bmaksud : bmaksud
# gini : gin
# emang : emang
# korea : korea
# regulasi : regulasi
# exo : exo
# ga : ga
# upload : upload
# foto : foto
# tradisi : tradisi
# wamil : wamil
# its : its
# okay : okay
# kxexxa : kxexxa
# bwanita : bwanita
# hamil : hamil
# kumpulan : kumpul
# berisiko : risiko
# komplikasi : komplikasi
# penyakit : sakit
# dijangkiti : jangkit
# justeru : justeru
# wanixexxa : wanixexxa
# elak : elak
# leka : leka
# sentiasa : sentiasa
# httxexxa : httxexxa
# bjadi : bjadi
# koper : koper
# sayur : sayur
# nikmatnya : nikmat
# silaturahmi : silaturahmi
# potensi : potensi
# mudik : mudik
# aktivitas : aktivitas
# bni : bni
# bocah : bocah
# the : the
# promised : promised
# neverland : neverland
# nyesel : nyesel
# dah : dah
# capek : capek
# ngelawan : ngelawan
# iblis : iblis
# sampe : sampe
# manusia : manusia
# ketemunya : ketemu
# bterus : bterus
# tuhh : tuhh
# setahun : tahun
# ketemu : ketemu
# bseluruh : bseluruh
# pelaku : laku
# pariwisata : pariwisata
# lovina : lovina
# ditarget : target
# mengandung : kandung
# mati : mati
# hidup : hidup
# lg : lg
# memperbanyak : banyak
# menyebabkan : sebab
# sakit : sakit
# bbalik : bbalik
# tambooonnn : tambooonnn
# wohooo : wohooo
# hooo : hooo
# tamboooonnnn : tamboooonnnn
# giranggggggggggggg : giranggggggggggggg
# mendaftarkan : daftar
# saudara : saudara
# terdekat : dekat
# sdxexxa : sdxexxa
# bdih : bdih
# gblokkkk : gblokkkk
# mengambil : ambil
# comirnaty : comirnaty
# terbaik : baik
# wanita : wanita
# kandungan : kandung
# bexexxa : bexexxa
# bbiasakan : bbiasakan
# pakai : pakai
# mari : mari
# pemakaian : pakai
# pelitup : pelitup
# mitigasi : mitigasi
# wabak : wabak
# pemakaiaxexxa : pemakaiaxexxa
# riski : riski
# kk : kk
# penduduk : duduk
# komplek : komplek
# hri : hri
# dtg : dtg
# ombir : ombir
# dll : dll
# jarang : jarang
# nampak : nampak
# dibilang : bilang
# goixexxa : goixexxa
# cluster : cluster
# takziah : takziah
# ngeeeeeng : ngeeeeeng
# ntar : ntar
# yasinan : yasinan
# tujuh : tujuh
# pendak : pendak
# semacamnya : macam
# jokowi : jokowi
# larang : larang
# anies : anies
# dki : dki
# aturan : atur
# menxexxa : menxexxa
# bsalah : bsalah
# perjuangan : juang
# berumur : umur
# munculnya : muncul
# solidaritas : solidaritas
# berjuaxexxa : berjuaxexxa
# mendaftar : daftar
# tanggungan : tanggung
# aplikasi : aplikasi
# mysejahtera : mysejahtera
# bantu : bantu
# dilindunxexxa : dilindunxexxa
# fungsi : fungsi
# xexxcperisai : xexxcperisai
# dirixexxd : dirixexxd
# berkesan : kesan
# dagu : dagu
# menyurutkan : surut
# rencana : rencana
# pemda : pemda
# wisatawan : wisatawan
# gov : gov
# agen : agen
# basmi : basmi
# abc : abc
# pxexxa : pxexxa
# kpk : kpk
# merespons : respons
# desakan : desa
# effendi : effendi
# ghazali : ghazali
# bukabukaan : bukabukaan
# dewa : dewa
# penerima : terima
# jatah : jatah
# bansos : bansos
# berjanji : janji
# membukanxexxa : membukanxexxa
# jayapura : jayapura
# papua : papua
# dosis : dosis
# ixexxa : ixexxa
# bkoramil : bkoramil
# tawangmangu : tawangmangu
# sertu : sertu
# parno : parno
# penerapan : terap
# menghimbau : menghimbau
# protokoler : protokoler
# pexexxa : pexexxa
# desanya : desa
# naruto : naruto
# wkwkwkw : wkwkwkw
# canda : canda
# hyong : hyong
# mematikan : mati
# hb : hb
# march : march
# laporan : lapor
# dos : dos
# mengikut : ikut
# negexexxa : negexexxa
# bpercepat : bpercepat
# pemprov : pemprov
# ntb : ntb
# gelar : gelar
# islamic : islamic
# center : center
# bserunya : bserunya
# muhajirin : muhajirin
# suriah : suriah
# dempetan : dempet
# garis : garis
# malu : malu
# kabur : kabur
# kayaknyaxfxfxxxexxa : kayaknyaxfxfxxxexxa
# bsetelah : bsetelah
# mengeluarkan : keluar
# larangan : larang
# memperbaharui : baharu
# ketentuan : tentu
# syarat : syarat
# perjalanan : jalan
# dalaxexxa : dalaxexxa
# divaksinxexxa : divaksinxexxa
# berita : berita
# dusun : dusun
# blekikngagliksleman : blekikngagliksleman
# dijemput : jemput
# ambulance : ambulance
# mhn : mhn
# perhatian : perhati
# infoxexxa : infoxexxa
# koramil : koramil
# bulu : bulu
# pengawalan : awal
# pengambilan : ambil
# gudang : gudang
# farmasixexxa : farmasixexxa
# bbaksos : bbaksos
# polri : polri
# yayasan : yayasan
# budha : budha
# tzu : tzu
# chi : chi
# indonesiapersatuan : indonesiapersatuan
# buddha : buddha
# islam : islam
# tioxexxa : tioxexxa
# hamxexxa : hamxexxa
# who : who
# jujur : jujur
# muak : muak
# bgt : bgt
# sm : sm
# panenkopi : panenkopi
# persen : persen
# gayo : gayo
# petani : tani
# kopi : kopi
# menggantungkan : gantung
# bkalau : bkalau
# tokoh : tokoh
# agama : agama
# terorisme : terorisme
# analogi : analogi
# bbabinkamtibmas : bbabinkamtibmas
# pakisjaya : pakisjaya
# nripka : nripka
# wawan : wawan
# sambang : sambang
# diologis : diologis
# kesehatanxexxa : kesehatanxexxa
# bpatuhi : bpatuhi
# menjaga : jaga
# melindungi : lindung
# selalxexxa : selalxexxa
# negeri : negeri
# terkait : kait
# korupsi : korupsi
# barang : barang
# direktorat : direktorat
# imigrasi : imigrasi
# kemenxexxa : kemenxexxa
# putus : putus
# mata : mata
# rantai : rantai
# bhasil : bhasil
# ct : ct
# klinik : klinik
# keterangan : terang
# negatifxexxa : negatifxexxa
# biasakan : biasa
# beffendi : beffendi
# gazali : gazal
# mendesak : desak
# bersikap : sikap
# transparan : transparan
# mengungkap : ungkap
# vendor : vendor
# proyek : proyek
# pengadaan : ada
# bantuan : bantu
# bansoxexxa : bansoxexxa
# bketua : bketua
# tppkk : tppkk
# berharap : harap
# kepengurusan : urus
# dibentuk : bentuk
# dikukuhkan : kukuh
# kelola : kelola
# keuangan : uang
# ramadhan : ramadhan
# soul : soul
# putra : putra
# tonton : tonton
# videonya : video
# dxexxa : dxexxa
# boalah : boalah
# gara : gara
# gabisa : gabisa
# up : up
# palbotxfxfxxexfxfxxexfxfxxexfxfxxexfxfxxexfxfxxexfxfxxexfxfxxe : palbotxfxfxxexfxfxxexfxfxxexfxfxxexfxfxxexfxfxxexfxfxxexfxfxxe
# prajurit : prajurit
# selesai : selesai
# prajxexxa : prajxexxa
# matlamat : matlamat
# utama : utama
# imunisasi : imunisasi
# hadapan : hadap
# mengurangkan : kurang
# membentuk : bentuk
# imuniti : imuniti
# kelomxexxa : kelomxexxa
# intramuskular : intramuskular
# otot : otot
# deltoid : deltoid
# bsleman : bsleman
# wabah : wabah
# serka : serka
# darmanto : darmanto
# babinsa : babinsa
# turi : turi
# kodim : kodim
# sleman : sleman
# gxexxa : gxexxa
# brs : brs
# lapangan : lapang
# gresik : gresik
# kelurahan : lurah
# bangunharjo : bangunharjo
# semarang : semarang
# aipda : aipda
# hengki : hengki
# pramono : pramono
# lurah : lurah
# sambanxexxa : sambanxexxa
# iya : iya
# mentaati : taat
# menghindari : hindar
# pastor : pastor
# daxexxa : daxexxa
# bzoom : bzoom
# meeting : meeting
# korbinmas : korbinmas
# baharkam : baharkam
# bgaesgaes : bgaesgaes
# khawatir : khawatir
# daftar : daftar
# kelompok : kelompok
# prioritas : prioritas
# nyebutin : nyebutin
# total : total
# tenaga : tenaga
# nakes : nakes
# sxexxa : sxexxa
# bmayoritas : bmayoritas
# sisa : sisa
# lainnyaxexxa : lainnyaxexxa
# bberikut : bberikut
# pekerja : kerja
# publik : publik
# profesxexxa : profesxexxa
# byaitu : byaitu
# diharapkan : harap
# selesxexxa : selesxexxa
# daulay : daulay
# rektor : rektor
# sumbangsih : sumbangsih
# bisanxexxa : bisanxexxa
# mimin : mimin
# bertiga : tiga
# suami : suami
# penyintas : sintas
# semangat : semangat
# sehat : sehat
# bekonomi : bekonomi
# gowa : gowa
# tumbuh : tumbuh
# pandemixcxacovid : pandemixcxacovid
# agong : agong
# seru : seru
# rakyat : rakyat
# berganding : ganding
# bahu : bahu
# tunai : tunai
# tanggungjawab : tanggungjawab
# lindungi : lindung
# menerusi : terusi
# vaksinaxexxa : vaksinaxexxa
# sambut : sambut
# rangka : rangka
# libatkan : libat
# samuda : samuda
# marnitxcxasamuda : marnitxcxasamuda
# nenek : nenek
# anti : anti
# banget : banget
# marah : marah
# diingetin : diingetin
# beliau : beliau
# suka : suka
# maxexxa : maxexxa
# bnew : bnew
# ekonomi : ekonomi
# has : has
# been : been
# published : published
# on : on
# sulsel : sulsel
# serunya : seru
# kayaknyaxfxfxx : kayaknyaxfxfxx
# penggunaan : guna
# dana : dana
# desa : desa
# diprioritaskan : prioritas
# yap : yap
# nasional : nasional
# proxexxa : proxexxa
# filipina : filipina
# melaporkan : lapor
# manixexxa : manixexxa
# bbetoll : bbetoll
# meningkatkan : tingkat
# resiko : resiko
# paparan : papar
# halaman : halaman
# bsupport : bsupport
# bingat : bingat
# coronaxexxa : coronaxexxa
# diskom : diskom
# rukun : rukun
# bpenutupan : bpenutupan
# berlaku : laku
# sukarukun : sukarukun
# sukatani : sukatani
# bekas : bekas
# covxexxa : covxexxa
# bkordinator : bkordinator
# mintarsih : mintarsih
# priorxexxa : priorxexxa
# bvaksinasi : bvaksinasi
# kotaini : kotaini
# bkorona : bkorona
# brengsekkkkkkkkkkkk : brengsekkkkkkkkkkkk
# kagak : kagak
# gua : gua
# nonton : nonton
# oor : oor
# bpunya : bpunya
# gratis : gratis
# mama : mama
# pocin : pocin
# ceritaku : cerita
# puskesmas : puskesmas
# tips : tips
# ama : ama
# saran : saran
# moeldoko : moeldoko
# fokus : fokus
# presiden : presiden
# menangani : tangan
# perbaikan : baik
# ekonomixexxa : ekonomixexxa
# gejala : gejala
# serius : serius
# bsurvei : bsurvei
# angkatan : angkat
# kerja : kerja
# sakernas : sakernas
# mencatat : catat
# pendapatan : dapat
# pengusahaxexxa : pengusahaxexxa
# denpasar : denpasar
# melejit : lejit
# angka : angka
# xcxaorang : xcxaorang
# bpos : bpos
# silawan : silawan
# sosialisasi : sosialisasi
# adubitin : adubitin
# persentase : persentase
# berusia : usia
# dus : dus
# gexexxa : gexexxa
# spesifik : spesifik
# mengalami : alami
# pasc : pasc
# kerap : kerap
# fatigue : fatigue
# kepxexxa : kepxexxa
# serba : serba
# cowo : cowo
# ramah : ramah
# buaya : buaya
# disangka : sangka
# bbertambah : bbertambah
# kematianxexxa : kematianxexxa
# bhal : bhal
# dikhawatirkan : khawatir
# daerah : daerah
# xfxfxxa : xfxfxxa
# bpersonel : bpersonel
# ditpolairud : ditpolairud
# polda : polda
# kaltim : kaltim
# patroli : patroli
# membagikan : bagi
# masxexxa : masxexxa
# btim : btim
# mempermudah : mudah
# verivikasi : verivikasi
# klaim : klaim
# bernama : nama
# kawankawan : kawankawan
# musisi : musisi
# jalanan : jalan
# difabel : difabel
# tunanetra : tunanetra
# mengisi : isi
# acara : acara
# musik : musik
# makassar : makassar
# wni : wni
# bertambah : tambah
# berasal : asal
# timor : timor
# leste : leste
# kuwait : kuwait
# bahraxexxa : bahraxexxa
# avp : avp
# penyiapan : siap
# dannhand : dannhand
# tidxexxa : tidxexxa
# bsaat : bsaat
# sumedang : sumedang
# pemberlakuan : laku
# paxexxa : paxexxa
# klaster : klaster
# bdukung : bdukung
# tersayang : sayang
# ale : ale
# handanovic : handanovic
# negatif : negatif
# xfxfxex : xfxfxex
# bsenin : bsenin
# penambahan : tambah
# ingatkan : ingat
# subjekxexxa : subjekxexxa
# ditambah : tambah
# read : read
# more : more
# bpertumbuhan : bpertumbuhan
# perlengkapan : lengkap
# ketinggalan : tinggal
# disiapkan : siap
# selengkapnya : lengkap
# bulk : bulk
# overfill : overfill
# kedatangan : datang
# merupakxexxa : merupakxexxa
# btak : btak
# tb : tb
# dicegah : cegah
# cari : cari
# info : info
# ulama : ulama
# gakxexxa : gakxexxa
# bdisaat : bdisaat
# sulit : sulit
# industri : industri
# rumah : rumah
# tangga : tangga
# dixexxa : dixexxa
# kemarin : kemarin
# disuntikkan : suntik
# rincian : rincian
# bganjar : bganjar
# arahan : arah
# guruguru : guruguru
# pengalamaxexxa : pengalamaxexxa
# bpengalamannya : bpengalamannya
# menggelar : gelar
# ptm : ptm
# smk : smk
# jateng : jateng
# murid : murid
# ganjar : ganjar
# terkonfirmasi : konfirmasi
# ternyaxexxa : ternyaxexxa
# mengimbau : imbau
# vxexxa : vxexxa
# mentri : tri
# kasih : kasih
# apresiasi : apresiasi
# kepala : kepala
# bsama : bsama
# menko : menko
# bidang : bidang
# perekonomian : ekonomi
# hartarto : hartarto
# keberkesanannya : kesan
# herd : herd
# imunity : imunity
# hrs : hrs
# klasifikasi : klasifikasi
# tertentuxexxa : tertentuxexxa
# bsobat : bsobat
# produktif : produktif
# darinxexxa : darinxexxa
# ysf : ysf
# tahan : tahan
# nnti : nnti
# bernyanyi : nyanyi
# lagu : lagu
# bareng : bareng
# peri : peri
# xfxfxx : xfxfxx
# kronologis : kronologis
# melayat : layat
# ditebxexxa : ditebxexxa
# tagih : tagih
# lagiblm : lagiblm
# jg : jg
# smpe : smpe
# laxexxa : laxexxa
# berjalan : jalan
# kalangan : kalang
# prixexxa : prixexxa
# ngobrol : ngobrol
# gus : gus
# muwafiq : muwafiq
# mundur : mundur
# dianggap : anggap
# gubernur : gubernur
# pandexexxa : pandexexxa
# httpsxexxa : httpsxexxa
# menyarankan : saran
# memxexxa : memxexxa
# bee : bee
# kedepan : depan
# ditamxexxa : ditamxexxa
# rsl : rsl
# ijen : ijen
# boulevard : boulevard
# desember : desember
# wibxexxa : wibxexxa
# smrc : smrc
# pemilih : pilih
# prabowo : prabowo
# pilpres : pilpres
# samxexxa : samxexxa
# bkenapa : bkenapa
# gembar : gembar
# gembor : gembor
# peraturan : atur
# pas : pas
# chanyeol : chanyeol
# doang : doang
# cuman : cuman
# ngga : ngga
# ngaduk : ngaduk
# dodol : dodol
# garutxfxfxxad : garutxfxfxxad
# kesedaran : dar
# sesuai : sesuai
# bkonsultasi : bkonsultasi
# penyaluran : salur
# langkat : langkat
# kunker : kunker
# dinsos : dinsos
# aceh : aceh
# jurnal : jurnal
# intinya : inti
# kaya : kaya
# org : org
# survei : survei
# yaxexxa : yaxexxa
# bknapa : bknapa
# diberitakan : berita
# yuuk : yuuk
# qta : qta
# sukseskan : sukses
# bits : bits
# ok : ok
# gaada : gaada
# grup : grup
# grgr : grgr
# gue : gue
# ngerti : ngerti
# tp : tp
# merchbot : merchbot
# gitu : gitu
# wamixexxa : wamixexxa
# bzona : bzona
# hijau : hijau
# subang : subang
# bpresiden : bpresiden
# menhan : menhan
# pakistan : pakistan
# terinfeksi : infeksi
# diamankan : aman
# bio : bio
# farma : farma
# via : via
# bicw : bicw
# desak : desak
# panggil : panggil
# herman : herman
# hery : hery
# alokasi : alokasi
# pajak : pajak
# sumber : sumber
# pendanaan : dana
# sektor : sektor
# bentuk : bentuk
# uxexxa : uxexxa
# waskita : waskita
# rugi : rugi
# trilyunan : trilyunan
# saham : saham
# anjlok : anjlok
# poin : poin
# terpaksa : paksa
# restrukturisasi : restrukturisasi
# hutang : hutang
# menjxexxa : menjxexxa
# bfasilitas : bfasilitas
# pembebasan : bebas
# bea : bea
# ketentuannya : tentu
# prihatin : prihatin
# kriminal : kriminal
# menyexexxa : menyexexxa
# urutan : urut
# axexxa : axexxa
# pembagian : bagi
# medis : medis
# gerakan : gera
# bermasker : masker
# kepulauan : pulau
# seribu : ribu
# upaxexxa : upaxexxa
# bhrs : bhrs
# aliran : alir
# trafik : trafik
# bergerak : gerak
# lancar : lancar
# jsahms : jsahms
# cuaca : cuaca
# sila : sila
# had : had
# laju : laju
# ditetapkxexxa : ditetapkxexxa
# btidak : btidak
# emg : emg
# dr : dr
# sbelum : sbelum
# arif : arif
# alvi : alvi
# terbukti : bukti
# mereknyaxexxa : mereknyaxexxa
# allah : allah
# mengasihani : kasihan
# bed : bed
# cepat : cepat
# berakhirxexxa : berakhirxexxa
# membutuhkan : butuh
# informasi : informasi
# seputar : putar
# bkecepatan : bkecepatan
# mendekati : dekat
# banakanak : banakanak
# wajib : wajib
# tes : tes
# amerika : amerika
# serikat : serikat
# meluas : luas
# kejadian : jadi
# rasisme : rasisme
# asia : asia
# dikota : kota
# new : new
# york : york
# dipicu : picu
# statexexxa : statexexxa
# indonesian : indonesian
# laksanakan : laksana
# bukti : bukti
# keseriusan : serius
# percepataxexxa : percepataxexxa
# bdibilang : bdibilang
# sehatt : sehatt
# bdampak : bdampak
# piknik : piknik
# tegal : tegal
# dilema : dilema
# perempuan : perempuan
# simak : simak
# pembahasan : bahas
# bmenkes : bmenkes
# posisi : posisi
# terbesar : besar
# bfarooq : bfarooq
# abdullah : abdullah
# tests : tests
# positive : positive
# tweets : tweets
# omarxcxaabdullah : omarxcxaabdullah
# divaksinasi : vaksinasi
# peserta : serta
# kabar : kabar
# sehari : hari
# konsumsi : konsumsi
# nutrisi : nutrisi
# imeta : imeta
# penciuxexxa : penciuxexxa
# bpolsek : bpolsek
# sawit : sawit
# blt : blt
# iii : iii
# kateguhan : kateguhan
# studi : studi
# terapi : terapi
# plasma : plasma
# konvalesen : konvalesen
# turunkan : turun
# bkpk : bkpk
# periksa : periksa
# ketua : ketua
# komisi : komisi
# viii : viii
# dpr : dpr
# juliari : juliari
# batubara : batubara
# bjangan : bjangan
# lupa : lupa
# memakai : pakai
# rumahkarena : rumahkarena
# diluar : luar
# sanaxexxa : sanaxexxa
# bhadapi : bhadapi
# berdampingan : damping
# pilihan : pilih
# cermati : cermat
# perixexxa : perixexxa
# warganya : warga
# berfoyafoya : berfoyafoya
# askari : askar
# merinci : merinci
# rp : rp
# gunxexxa : gunxexxa
# sang : sang
# mentari : mentari
# bersinar : sinar
# terang : terang
# panas : panas
# menyengat : sengat
# gambaran : gambar
# namunxexxa : namunxexxa
# bgubernur : bgubernur
# tekankan : tekan
# kebijakan : bijak
# provinsxexxa : provinsxexxa
# tasikmalaya : tasikmalaya
# patut : patut
# diacungi : acung
# jempol : jempol
# menerjang : terjang
# banjir : banjir
# dng : dng
# membawa : bawa
# bandara : bandara
# apt : apt
# pranoto : pranoto
# samarinda : samarinda
# kalimantan : kalimantan
# timur : timur
# berencana : rencana
# alat : alat
# deteksi : deteksi
# genose : genose
# bwaspada : bwaspada
# pakailah : pakai
# {'satgas': 'satgas', 'covid': 'covid', 'mengaku': 'aku', 'kepatuhan': 'patuh', 'masyarakat': 'masyarakat', 'protokol': 'protokol', 'kesehatan': 'sehat', 'menurun': 'turun', 'dilaksanakannya': 'laksana', 'vaksin': 'vaksin', 'bahas': 'bahas', 'long': 'long', 'sebutannya': 'sebut', 'diganti': 'ganti', 'post': 'post', 'acute': 'acute', 'sequelae': 'sequelae', 'sarscov': 'sarscov', 'pascxexxa': 'pascxexxa', 'aneh': 'aneh', 'alasannya': 'alas', 'korona': 'korona', 'bolehkah': 'boleh', 'raya': 'raya', 'kampung': 'kampung', 'biggest': 'biggest', 'wish': 'wish', 'masuk': 'masuk', 'surga': 'surga', 'orang': 'orang', 'sayangin': 'sayangin', 'konser': 'konser', 'day': 'day', 'belum': 'belum', 'kesampean': 'sampean', 'anjing': 'anjing', 'adakah': 'ada', 'petandaaaa': 'petandaaaa', 'bpln': 'bpln', 'berkomitmen': 'komitmen', 'mendukung': 'dukung', 'program': 'program', 'vaksinasi': 'vaksinasi', 'dijalankan': 'jalan', 'pemerintah': 'perintah', 'diwujudkan': 'wujud', 'vaksinisasi': 'vaksin', 'kenyataan': 'nyata', 'memaklumkan': 'maklum', 'perkembangan': 'kembang', 'kompaun': 'kompaun', 'pelanggaran': 'langgar', 'sop': 'sop', 'kuantan': 'antan', 'barubaru': 'barubaru', 'anggota': 'anggota', 'dprd': 'dprd', 'provinsi': 'provinsi', 'lampung': 'lampung', 'terima': 'terima', 'vaksinxcxacovid': 'vaksinxcxacovid', 'data': 'data', 'kematian': 'mati', 'maret': 'maret', 'yamani': 'yamani', 'salam': 'salam', 'albakri': 'albakri', 'hadith': 'hadith', 'khusus': 'khusus', 'double': 'double', 'standard': 'standard', 'menghukum': 'hukum', 'pencuri': 'curi', 'amaran': 'amar', 'dalxexxa': 'dalxexxa', 'terapkan': 'terap', 'pendisiplinan': 'disiplin', 'prokes': 'prokes', 'antisipasi': 'antisipasi', 'personil': 'personil', 'sat': 'sat', 'polair': 'polair', 'polres': 'polres', 'jembrana': 'jembrana', 'lakukan': 'laku', 'kurve': 'kurve', 'kebersihan': 'bersih', 'siscajkt': 'siscajkt', 'pandemi': 'pandemi', 'susah': 'susah', 'dapatkan': 'dapat', 'uang': 'uang', 'sampingan': 'samping', 'yuk': 'yuk', 'langsung': 'langsung', 'hubungi': 'hubung', 'whatsapp': 'whatsapp', 'gt': 'gt', 'selamat': 'selamat', 'hut': 'hut', 'rsud': 'rsud', 'panembahan': 'panembahan', 'senopati': 'senopati', 'bantul': 'bantul', 'hati': 'hati', 'tekad': 'tekad', 'pelayanan': 'layan', 'xfxfxxaa': 'xfxfxxaa', 'xexxa': 'xexxa', 'perdana': 'perdana', 'menteri': 'menteri', 'tan': 'tan', 'sri': 'sri', 'muhyiddin': 'muhyiddin', 'yassin': 'yassin', 'jaminan': 'jamin', 'kerajaan': 'raja', 'berusaha': 'usaha', 'membantu': 'bantu', 'memulihkan': 'pulih', 'kehidupan': 'hidup', 'rakyaxexxa': 'rakyaxexxa', 'dosen': 'dosen', 'usu': 'usu', 'meninggal': 'tinggal', 'terpapar': 'papar', 'kathrinajkt': 'kathrinajkt', 'kumulatif': 'kumulatif', 'konfirmasi': 'konfirmasi', 'positif': 'positif', 'indonesia': 'indonesia', 'mencapai': 'capai', 'juta': 'juta', 'tepatnya': 'tepat', 'sexexxa': 'sexexxa', 'bprogram': 'bprogram', 'wujud': 'wujud', 'nyata': 'nyata', 'kesadaran': 'sadar', 'pln': 'pln', 'menekan': 'tekan', 'penyebaran': 'sebar', 'virus': 'virus', 'mexexxa': 'mexexxa', 'marshajkt': 'marshajkt', 'bsecara': 'bsecara', 'bertahap': 'tahap', 'pegawai': 'pegawai', 'memastikanxexxa': 'memastikanxexxa', 'yaudahlah': 'yaudahlah', 'poto': 'poto', 'gapapa': 'gapapa', 'lo': 'lo', 'pake': 'pake', 'alesan': 'alesan', 'gabole': 'gabole', 'kumpul': 'kumpul', 'bxfxfxxc': 'bxfxfxxc', 'pemerkasaan': 'perkasa', 'komuniti': 'komuniti', 'senjata': 'senjata', 'usaha': 'usaha', 'membendung': 'bendung', 'penularan': 'tular', 'xfxfxxc': 'xfxfxxc', 'pantau': 'pantau', 'kawaxexxa': 'kawaxexxa', 'syukram': 'syukram', 'akhi': 'akh', 'sy': 'sy', 'diajak': 'ajak', 'kemenparekraf': 'kemenparekraf', 'negara': 'negara', 'lemuria': 'lemuria', 'mengikuti': 'ikut', 'uji': 'uji', 'coba': 'coba', 'wisata': 'wisata', 'era': 'era', 'graciajkt': 'graciajkt', 'edaran': 'edar', 'pp': 'pp', 'muhammadiyah': 'muhammadiyah', 'tuntunan': 'tuntun', 'ibadah': 'ibadah', 'ramadan': 'ramadan', 'kondisi': 'kondisi', 'darurat': 'darurat', 'astrazeneca': 'astrazeneca', ' ...
# ------------------------
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=352.0), HTML(value='')))
# 0      [satgas, covid, aku, patuh, masyarakat, protok...
# 1      [bahas, long, covid, sebut, ganti, post, acute...
# 2                                   [aneh, alas, korona]
# 3                                 [boleh, raya, kampung]
# 4      [biggest, wish, masuk, surga, orang, orang, sa...
#                              ...
# 347    [bsebanyak, juta, duduk, indonesia, vaksin, ma...
# 348    [tugas, vaksinasi, covid, tasikmalaya, patut, ...
# 349    [bandara, apt, pranoto, samarinda, kalimantan,...
# 350    [kepala, desa, korupsi, dana, bantu, covid, be...
# 351    [bwaspada, covid, pakai, masker, rumah, patuh,...
# Name: tweet_tokens_stemmed, Length: 352, dtype: object

# %%
TWEET_DATA.to_csv("new_data.csv")

# %%
new_data=pd.read_csv('new_data.csv')

# %%
x=new_data['tweet_tokens_stemmed']
y=new_data['label']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

vectorizer = CountVectorizer()
data_vektor = vectorizer.fit_transform(x)
lda = LatentDirichletAllocation(n_components = 7, random_state = 42)
lda.fit(data_vektor)
# Out:
# LatentDirichletAllocation(n_components=7, random_state=42)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
for index, topic in enumerate(lda.components_):
  tmps = [vectorizer.get_feature_names()[i] for i in topic.argsort()[-15:]]
  text = " ".join(str(topik) for topik in tmps)
  wordcloud = WordCloud(max_words=50,colormap='Set3', background_color="black").generate(text)
  plt.figure(figsize=(10,5))
  plt.imshow(wordcloud)
  plt.show()
